# %%
import numpy as np
import pandas as pd
import pathlib
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)

"""## The Auto MPG dataset

The dataset is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/).

### Get the data
First download the dataset.
"""

dataset_path = keras.utils.get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path

"""Import it using pandas"""

column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']
dataset = pd.read_csv(dataset_path, names=column_names,
                      na_values = "?", comment='\t',
                      sep=" ", skipinitialspace=True)

dataset.tail()

# TODO: replace `your-gcs-bucket` with the name of the Storage bucket you created earlier
BUCKET = 'gs://your-gcs-bucket'

"""### Clean the data

The dataset contains a few unknown values.
"""

dataset.isna().sum()

"""To keep this initial tutorial simple drop those rows."""

dataset = dataset.dropna()

"""The `"Origin"` column is really categorical, not numeric. So convert that to a one-hot:"""

dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})

dataset = pd.get_dummies(dataset, prefix='', prefix_sep='')
dataset.tail()

"""### Split the data into train and test

Now split the dataset into a training set and a test set.

We will use the test set in the final evaluation of our model.
"""

train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

"""### Inspect the data

Have a quick look at the joint distribution of a few pairs of columns from the training set.

Also look at the overall statistics:
"""

train_stats = train_dataset.describe()
train_stats.pop("MPG")
train_stats = train_stats.transpose()
train_stats

"""### Split features from labels

Separate the target value, or "label", from the features. This label is the value that you will train the model to predict.
"""

train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

"""### Normalize the data

Look again at the `train_stats` block above and note how different the ranges of each feature are.

It is good practice to normalize features that use different scales and ranges. Although the model *might* converge without feature normalization, it makes training more difficult, and it makes the resulting model dependent on the choice of units used in the input.

Note: Although we intentionally generate these statistics from only the training dataset, these statistics will also be used to normalize the test dataset. We need to do that to project the test dataset into the same distribution that the model has been trained on.
"""

def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

"""This normalized data is what we will use to train the model.

Caution: The statistics used to normalize the inputs here (mean and standard deviation) need to be applied to any other data that is fed to the model, along with the one-hot encoding that we did earlier.  That includes the test set as well as live data when the model is used in production.

## The model

### Build the model

Let's build our model. Here, we'll use a `Sequential` model with two densely connected hidden layers, and an output layer that returns a single, continuous value. The model building steps are wrapped in a function, `build_model`, since we'll create a second model, later on.
"""

def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()

"""### Inspect the model

Use the `.summary` method to print a simple description of the model
"""

model.summary()

"""Now try out the model. Take a batch of `10` examples from the training data and call `model.predict` on it.

It seems to be working, and it produces a result of the expected shape and type.

### Train the model

Train the model for 1000 epochs, and record the training and validation accuracy in the `history` object.

Visualize the model's training progress using the stats stored in the `history` object.

This graph shows little improvement, or even degradation in the validation error after about 100 epochs. Let's update the `model.fit` call to automatically stop training when the validation score doesn't improve. We'll use an *EarlyStopping callback* that tests a training condition for  every epoch. If a set amount of epochs elapses without showing improvement, then automatically stop the training.

You can learn more about this callback [here](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping).
"""

model = build_model()

EPOCHS = 1000

# The patience parameter is the amount of epochs to check for improvement
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

early_history = model.fit(normed_train_data, train_labels, 
                    epochs=EPOCHS, validation_split = 0.2, 
                    callbacks=[early_stop])


# Export model and save to GCS
model.save(BUCKET + '/mpg/model')
# Out:
# 1.15.5
# Downloading data from http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 1us/step
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                640
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# Train on 251 samples, validate on 63 samples
# 2022-02-26 12:11:53.186016: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-02-26 12:11:53.190569: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5616360c1110 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-02-26 12:11:53.190616: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-02-26 12:11:53.191076: I tensorflow/core/common_runtime/process_util.cc:136] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Epoch 1/1000
# 251/251 [==============================] - 1s 3ms/sample - loss: 564.0346 - mean_absolute_error: 22.4367 - mean_squared_error: 564.0346 - val_loss: 555.5696 - val_mean_absolute_error: 22.1932 - val_mean_squared_error: 555.5696
# Epoch 2/1000
# 251/251 [==============================] - 0s 137us/sample - loss: 514.4132 - mean_absolute_error: 21.3004 - mean_squared_error: 514.4132 - val_loss: 505.2089 - val_mean_absolute_error: 21.0395 - val_mean_squared_error: 505.2089
# Epoch 3/1000
# 251/251 [==============================] - 0s 103us/sample - loss: 464.6687 - mean_absolute_error: 20.1292 - mean_squared_error: 464.6687 - val_loss: 448.2873 - val_mean_absolute_error: 19.6776 - val_mean_squared_error: 448.2873
# Epoch 4/1000
# 251/251 [==============================] - 0s 100us/sample - loss: 409.8325 - mean_absolute_error: 18.7624 - mean_squared_error: 409.8325 - val_loss: 387.3199 - val_mean_absolute_error: 18.1240 - val_mean_squared_error: 387.3199
# Epoch 5/1000
# 251/251 [==============================] - 0s 133us/sample - loss: 351.1777 - mean_absolute_error: 17.2164 - mean_squared_error: 351.1777 - val_loss: 321.7605 - val_mean_absolute_error: 16.3447 - val_mean_squared_error: 321.7604
# Epoch 6/1000
# 251/251 [==============================] - 0s 106us/sample - loss: 290.4057 - mean_absolute_error: 15.4656 - mean_squared_error: 290.4057 - val_loss: 257.3632 - val_mean_absolute_error: 14.4211 - val_mean_squared_error: 257.3632
# Epoch 7/1000
# 251/251 [==============================] - 0s 100us/sample - loss: 230.5035 - mean_absolute_error: 13.6097 - mean_squared_error: 230.5035 - val_loss: 196.1430 - val_mean_absolute_error: 12.3993 - val_mean_squared_error: 196.1430
# Epoch 8/1000
# 251/251 [==============================] - 0s 143us/sample - loss: 174.4103 - mean_absolute_error: 11.6810 - mean_squared_error: 174.4103 - val_loss: 140.3786 - val_mean_absolute_error: 10.3630 - val_mean_squared_error: 140.3786
# Epoch 9/1000
# 251/251 [==============================] - 0s 158us/sample - loss: 124.0468 - mean_absolute_error: 9.7090 - mean_squared_error: 124.0468 - val_loss: 93.5294 - val_mean_absolute_error: 8.2978 - val_mean_squared_error: 93.5294
# Epoch 10/1000
# 251/251 [==============================] - 0s 160us/sample - loss: 83.2658 - mean_absolute_error: 7.7292 - mean_squared_error: 83.2658 - val_loss: 59.6988 - val_mean_absolute_error: 6.5770 - val_mean_squared_error: 59.6988
# Epoch 11/1000
# 251/251 [==============================] - 0s 163us/sample - loss: 54.0769 - mean_absolute_error: 5.9632 - mean_squared_error: 54.0769 - val_loss: 38.4202 - val_mean_absolute_error: 5.2810 - val_mean_squared_error: 38.4202
# Epoch 12/1000
# 251/251 [==============================] - 0s 157us/sample - loss: 36.2269 - mean_absolute_error: 4.6510 - mean_squared_error: 36.2269 - val_loss: 28.3581 - val_mean_absolute_error: 4.4516 - val_mean_squared_error: 28.3581
# Epoch 13/1000
# 251/251 [==============================] - 0s 336us/sample - loss: 26.9905 - mean_absolute_error: 3.9543 - mean_squared_error: 26.9905 - val_loss: 24.0476 - val_mean_absolute_error: 3.9083 - val_mean_squared_error: 24.0476
# Epoch 14/1000
# 251/251 [==============================] - 0s 182us/sample - loss: 22.5127 - mean_absolute_error: 3.5889 - mean_squared_error: 22.5127 - val_loss: 21.6009 - val_mean_absolute_error: 3.5906 - val_mean_squared_error: 21.6009
# Epoch 15/1000
# 251/251 [==============================] - 0s 288us/sample - loss: 19.4909 - mean_absolute_error: 3.3548 - mean_squared_error: 19.4909 - val_loss: 19.7821 - val_mean_absolute_error: 3.4328 - val_mean_squared_error: 19.7821
# Epoch 16/1000
# 251/251 [==============================] - 0s 279us/sample - loss: 17.5322 - mean_absolute_error: 3.1745 - mean_squared_error: 17.5322 - val_loss: 17.9970 - val_mean_absolute_error: 3.3355 - val_mean_squared_error: 17.9970
# Epoch 17/1000
# 251/251 [==============================] - 0s 145us/sample - loss: 16.0079 - mean_absolute_error: 3.0312 - mean_squared_error: 16.0079 - val_loss: 16.3968 - val_mean_absolute_error: 3.1635 - val_mean_squared_error: 16.3967
# Epoch 18/1000
# 251/251 [==============================] - 0s 186us/sample - loss: 14.8711 - mean_absolute_error: 2.9004 - mean_squared_error: 14.8711 - val_loss: 14.9921 - val_mean_absolute_error: 2.9986 - val_mean_squared_error: 14.9921
# Epoch 19/1000
# 251/251 [==============================] - 0s 159us/sample - loss: 13.7595 - mean_absolute_error: 2.7765 - mean_squared_error: 13.7595 - val_loss: 13.8191 - val_mean_absolute_error: 2.9323 - val_mean_squared_error: 13.8191
# Epoch 20/1000
# 251/251 [==============================] - 0s 177us/sample - loss: 12.7054 - mean_absolute_error: 2.6497 - mean_squared_error: 12.7054 - val_loss: 13.1174 - val_mean_absolute_error: 2.7867 - val_mean_squared_error: 13.1174
# Epoch 21/1000
# 251/251 [==============================] - 0s 132us/sample - loss: 12.1272 - mean_absolute_error: 2.5553 - mean_squared_error: 12.1272 - val_loss: 11.9264 - val_mean_absolute_error: 2.7119 - val_mean_squared_error: 11.9264
# Epoch 22/1000
# 251/251 [==============================] - 0s 176us/sample - loss: 11.4909 - mean_absolute_error: 2.4873 - mean_squared_error: 11.4909 - val_loss: 11.4245 - val_mean_absolute_error: 2.6309 - val_mean_squared_error: 11.4245
# Epoch 23/1000
# 251/251 [==============================] - 0s 154us/sample - loss: 10.9358 - mean_absolute_error: 2.3832 - mean_squared_error: 10.9358 - val_loss: 11.0164 - val_mean_absolute_error: 2.5542 - val_mean_squared_error: 11.0164
# Epoch 24/1000
# 251/251 [==============================] - 0s 216us/sample - loss: 10.5785 - mean_absolute_error: 2.3751 - mean_squared_error: 10.5785 - val_loss: 10.4088 - val_mean_absolute_error: 2.4638 - val_mean_squared_error: 10.4088
# Epoch 25/1000
# 251/251 [==============================] - 0s 142us/sample - loss: 10.0092 - mean_absolute_error: 2.2908 - mean_squared_error: 10.0092 - val_loss: 9.9962 - val_mean_absolute_error: 2.4202 - val_mean_squared_error: 9.9962
# Epoch 26/1000
# 251/251 [==============================] - 0s 159us/sample - loss: 9.9067 - mean_absolute_error: 2.2377 - mean_squared_error: 9.9067 - val_loss: 9.7647 - val_mean_absolute_error: 2.3996 - val_mean_squared_error: 9.7647
# Epoch 27/1000
# 251/251 [==============================] - 0s 147us/sample - loss: 9.5666 - mean_absolute_error: 2.2216 - mean_squared_error: 9.5666 - val_loss: 9.8733 - val_mean_absolute_error: 2.4662 - val_mean_squared_error: 9.8733
# Epoch 28/1000
# 251/251 [==============================] - 0s 153us/sample - loss: 8.9727 - mean_absolute_error: 2.1163 - mean_squared_error: 8.9727 - val_loss: 9.5992 - val_mean_absolute_error: 2.3391 - val_mean_squared_error: 9.5992
# Epoch 29/1000
# 251/251 [==============================] - 0s 141us/sample - loss: 8.9924 - mean_absolute_error: 2.1665 - mean_squared_error: 8.9924 - val_loss: 9.2992 - val_mean_absolute_error: 2.3571 - val_mean_squared_error: 9.2992
# Epoch 30/1000
# 251/251 [==============================] - 0s 148us/sample - loss: 8.8809 - mean_absolute_error: 2.0722 - mean_squared_error: 8.8809 - val_loss: 9.4173 - val_mean_absolute_error: 2.3084 - val_mean_squared_error: 9.4173
# Epoch 31/1000
# 251/251 [==============================] - 0s 159us/sample - loss: 8.5482 - mean_absolute_error: 2.0840 - mean_squared_error: 8.5482 - val_loss: 8.9985 - val_mean_absolute_error: 2.2964 - val_mean_squared_error: 8.9985
# Epoch 32/1000
# 251/251 [==============================] - 0s 156us/sample - loss: 8.3204 - mean_absolute_error: 2.0488 - mean_squared_error: 8.3204 - val_loss: 9.0760 - val_mean_absolute_error: 2.3399 - val_mean_squared_error: 9.0760
# Epoch 33/1000
# 251/251 [==============================] - 0s 151us/sample - loss: 8.3602 - mean_absolute_error: 2.0294 - mean_squared_error: 8.3602 - val_loss: 8.8126 - val_mean_absolute_error: 2.2994 - val_mean_squared_error: 8.8126
# Epoch 34/1000
# 251/251 [==============================] - 0s 152us/sample - loss: 8.3427 - mean_absolute_error: 2.0524 - mean_squared_error: 8.3427 - val_loss: 9.1573 - val_mean_absolute_error: 2.3560 - val_mean_squared_error: 9.1573
# Epoch 35/1000
# 251/251 [==============================] - 0s 164us/sample - loss: 8.1103 - mean_absolute_error: 2.0030 - mean_squared_error: 8.1103 - val_loss: 8.4879 - val_mean_absolute_error: 2.2494 - val_mean_squared_error: 8.4880
# Epoch 36/1000
# 251/251 [==============================] - 0s 150us/sample - loss: 7.8453 - mean_absolute_error: 1.9861 - mean_squared_error: 7.8453 - val_loss: 8.4975 - val_mean_absolute_error: 2.2108 - val_mean_squared_error: 8.4975
# Epoch 37/1000
# 251/251 [==============================] - 0s 158us/sample - loss: 8.0432 - mean_absolute_error: 1.9979 - mean_squared_error: 8.0432 - val_loss: 8.6501 - val_mean_absolute_error: 2.2895 - val_mean_squared_error: 8.6500
# Epoch 38/1000
# 251/251 [==============================] - 0s 126us/sample - loss: 7.8001 - mean_absolute_error: 1.9530 - mean_squared_error: 7.8001 - val_loss: 8.7081 - val_mean_absolute_error: 2.1990 - val_mean_squared_error: 8.7081
# Epoch 39/1000
# 251/251 [==============================] - 0s 108us/sample - loss: 7.7438 - mean_absolute_error: 1.9375 - mean_squared_error: 7.7438 - val_loss: 8.5064 - val_mean_absolute_error: 2.1820 - val_mean_squared_error: 8.5064
# Epoch 40/1000
# 251/251 [==============================] - 0s 112us/sample - loss: 7.8173 - mean_absolute_error: 1.9894 - mean_squared_error: 7.8173 - val_loss: 8.4801 - val_mean_absolute_error: 2.2015 - val_mean_squared_error: 8.4801
# Epoch 41/1000
# 251/251 [==============================] - 0s 112us/sample - loss: 7.4876 - mean_absolute_error: 1.9237 - mean_squared_error: 7.4876 - val_loss: 8.4872 - val_mean_absolute_error: 2.3066 - val_mean_squared_error: 8.4872
# Epoch 42/1000
# 251/251 [==============================] - 0s 176us/sample - loss: 7.5119 - mean_absolute_error: 1.9287 - mean_squared_error: 7.5119 - val_loss: 8.4946 - val_mean_absolute_error: 2.2559 - val_mean_squared_error: 8.4946
# Epoch 43/1000
# 251/251 [==============================] - 0s 226us/sample - loss: 7.5761 - mean_absolute_error: 1.9192 - mean_squared_error: 7.5761 - val_loss: 8.2202 - val_mean_absolute_error: 2.1951 - val_mean_squared_error: 8.2202
# Epoch 44/1000
# 251/251 [==============================] - 0s 148us/sample - loss: 7.2469 - mean_absolute_error: 1.8990 - mean_squared_error: 7.2469 - val_loss: 8.3975 - val_mean_absolute_error: 2.2105 - val_mean_squared_error: 8.3975
# Epoch 45/1000
# 251/251 [==============================] - 0s 174us/sample - loss: 7.4424 - mean_absolute_error: 1.9305 - mean_squared_error: 7.4424 - val_loss: 8.5474 - val_mean_absolute_error: 2.2330 - val_mean_squared_error: 8.5474
# Epoch 46/1000
# 251/251 [==============================] - 0s 146us/sample - loss: 7.3685 - mean_absolute_error: 1.9409 - mean_squared_error: 7.3685 - val_loss: 8.2973 - val_mean_absolute_error: 2.2408 - val_mean_squared_error: 8.2973
# Epoch 47/1000
# 251/251 [==============================] - 0s 138us/sample - loss: 7.2295 - mean_absolute_error: 1.8874 - mean_squared_error: 7.2295 - val_loss: 8.4912 - val_mean_absolute_error: 2.1484 - val_mean_squared_error: 8.4912
# Epoch 48/1000
# 251/251 [==============================] - 0s 158us/sample - loss: 7.3969 - mean_absolute_error: 1.9239 - mean_squared_error: 7.3969 - val_loss: 8.3569 - val_mean_absolute_error: 2.2377 - val_mean_squared_error: 8.3569
# Epoch 49/1000
# 251/251 [==============================] - 0s 145us/sample - loss: 7.3228 - mean_absolute_error: 1.8955 - mean_squared_error: 7.3228 - val_loss: 8.0791 - val_mean_absolute_error: 2.1797 - val_mean_squared_error: 8.0791
# Epoch 50/1000
# 251/251 [==============================] - 0s 167us/sample - loss: 7.2460 - mean_absolute_error: 1.8873 - mean_squared_error: 7.2460 - val_loss: 8.2973 - val_mean_absolute_error: 2.1765 - val_mean_squared_error: 8.2973
# Epoch 51/1000
# 251/251 [==============================] - 0s 154us/sample - loss: 7.0950 - mean_absolute_error: 1.8803 - mean_squared_error: 7.0950 - val_loss: 8.2114 - val_mean_absolute_error: 2.1916 - val_mean_squared_error: 8.2114
# Epoch 52/1000
# 251/251 [==============================] - 0s 181us/sample - loss: 7.1850 - mean_absolute_error: 1.8909 - mean_squared_error: 7.1850 - val_loss: 8.4574 - val_mean_absolute_error: 2.2419 - val_mean_squared_error: 8.4574
# Epoch 53/1000
# 251/251 [==============================] - 0s 146us/sample - loss: 7.1110 - mean_absolute_error: 1.8945 - mean_squared_error: 7.1110 - val_loss: 8.4011 - val_mean_absolute_error: 2.2586 - val_mean_squared_error: 8.4011
# Epoch 54/1000
# 251/251 [==============================] - 0s 151us/sample - loss: 7.0253 - mean_absolute_error: 1.8675 - mean_squared_error: 7.0253 - val_loss: 8.0134 - val_mean_absolute_error: 2.1714 - val_mean_squared_error: 8.0134
# Epoch 55/1000
# 251/251 [==============================] - 0s 175us/sample - loss: 6.9089 - mean_absolute_error: 1.8463 - mean_squared_error: 6.9089 - val_loss: 8.1422 - val_mean_absolute_error: 2.1400 - val_mean_squared_error: 8.1422
# Epoch 56/1000
# 251/251 [==============================] - 0s 166us/sample - loss: 6.9320 - mean_absolute_error: 1.8577 - mean_squared_error: 6.9320 - val_loss: 8.3025 - val_mean_absolute_error: 2.2705 - val_mean_squared_error: 8.3025
# Epoch 57/1000
# 251/251 [==============================] - 0s 169us/sample - loss: 6.9002 - mean_absolute_error: 1.8601 - mean_squared_error: 6.9002 - val_loss: 8.2758 - val_mean_absolute_error: 2.2203 - val_mean_squared_error: 8.2758
# Epoch 58/1000
# 251/251 [==============================] - 0s 156us/sample - loss: 6.9574 - mean_absolute_error: 1.8632 - mean_squared_error: 6.9574 - val_loss: 8.3609 - val_mean_absolute_error: 2.2308 - val_mean_squared_error: 8.3609
# Epoch 59/1000
# 251/251 [==============================] - 0s 148us/sample - loss: 7.0391 - mean_absolute_error: 1.8495 - mean_squared_error: 7.0391 - val_loss: 8.0523 - val_mean_absolute_error: 2.1307 - val_mean_squared_error: 8.0523
# Epoch 60/1000
# 251/251 [==============================] - 0s 188us/sample - loss: 6.9008 - mean_absolute_error: 1.8442 - mean_squared_error: 6.9008 - val_loss: 8.2028 - val_mean_absolute_error: 2.2553 - val_mean_squared_error: 8.2028
# Epoch 61/1000
# 251/251 [==============================] - 0s 141us/sample - loss: 6.8902 - mean_absolute_error: 1.8543 - mean_squared_error: 6.8902 - val_loss: 8.2663 - val_mean_absolute_error: 2.1545 - val_mean_squared_error: 8.2663
# Epoch 62/1000
# 251/251 [==============================] - 0s 177us/sample - loss: 6.8450 - mean_absolute_error: 1.8458 - mean_squared_error: 6.8450 - val_loss: 8.0198 - val_mean_absolute_error: 2.1811 - val_mean_squared_error: 8.0198
# Epoch 63/1000
# 251/251 [==============================] - 0s 148us/sample - loss: 6.8582 - mean_absolute_error: 1.8369 - mean_squared_error: 6.8582 - val_loss: 8.0504 - val_mean_absolute_error: 2.1804 - val_mean_squared_error: 8.0504
# Epoch 64/1000
# 251/251 [==============================] - 0s 157us/sample - loss: 6.8465 - mean_absolute_error: 1.8444 - mean_squared_error: 6.8465 - val_loss: 7.9805 - val_mean_absolute_error: 2.1693 - val_mean_squared_error: 7.9805
# Epoch 65/1000
# 251/251 [==============================] - 0s 191us/sample - loss: 6.7201 - mean_absolute_error: 1.8137 - mean_squared_error: 6.7201 - val_loss: 8.0261 - val_mean_absolute_error: 2.1300 - val_mean_squared_error: 8.0261
# Epoch 66/1000
# 251/251 [==============================] - 0s 166us/sample - loss: 6.6329 - mean_absolute_error: 1.8116 - mean_squared_error: 6.6329 - val_loss: 8.0209 - val_mean_absolute_error: 2.1088 - val_mean_squared_error: 8.0209
# Epoch 67/1000
# 251/251 [==============================] - 0s 174us/sample - loss: 6.7411 - mean_absolute_error: 1.8297 - mean_squared_error: 6.7411 - val_loss: 7.9751 - val_mean_absolute_error: 2.1596 - val_mean_squared_error: 7.9751
# Epoch 68/1000
# 251/251 [==============================] - 0s 161us/sample - loss: 6.6519 - mean_absolute_error: 1.7869 - mean_squared_error: 6.6519 - val_loss: 8.1110 - val_mean_absolute_error: 2.1825 - val_mean_squared_error: 8.1110
# Epoch 69/1000
# 251/251 [==============================] - 0s 161us/sample - loss: 6.6981 - mean_absolute_error: 1.8096 - mean_squared_error: 6.6981 - val_loss: 7.9203 - val_mean_absolute_error: 2.1650 - val_mean_squared_error: 7.9203
# Epoch 70/1000
# 251/251 [==============================] - 0s 158us/sample - loss: 6.5999 - mean_absolute_error: 1.8134 - mean_squared_error: 6.5999 - val_loss: 7.7419 - val_mean_absolute_error: 2.1347 - val_mean_squared_error: 7.7419
# Epoch 71/1000
# 251/251 [==============================] - 0s 173us/sample - loss: 6.7173 - mean_absolute_error: 1.8126 - mean_squared_error: 6.7173 - val_loss: 7.9253 - val_mean_absolute_error: 2.2043 - val_mean_squared_error: 7.9253
# Epoch 72/1000
# 251/251 [==============================] - 0s 187us/sample - loss: 6.5060 - mean_absolute_error: 1.7979 - mean_squared_error: 6.5060 - val_loss: 8.1497 - val_mean_absolute_error: 2.2071 - val_mean_squared_error: 8.1497
# Epoch 73/1000
# 251/251 [==============================] - 0s 191us/sample - loss: 6.7010 - mean_absolute_error: 1.8031 - mean_squared_error: 6.7010 - val_loss: 7.9133 - val_mean_absolute_error: 2.1420 - val_mean_squared_error: 7.9133
# Epoch 74/1000
# 251/251 [==============================] - 0s 195us/sample - loss: 6.4426 - mean_absolute_error: 1.7686 - mean_squared_error: 6.4426 - val_loss: 8.0190 - val_mean_absolute_error: 2.1547 - val_mean_squared_error: 8.0190
# Epoch 75/1000
# 251/251 [==============================] - 0s 204us/sample - loss: 6.4580 - mean_absolute_error: 1.8062 - mean_squared_error: 6.4580 - val_loss: 7.9355 - val_mean_absolute_error: 2.1522 - val_mean_squared_error: 7.9355
# Epoch 76/1000
# 251/251 [==============================] - 0s 200us/sample - loss: 6.5435 - mean_absolute_error: 1.7864 - mean_squared_error: 6.5435 - val_loss: 7.8361 - val_mean_absolute_error: 2.1347 - val_mean_squared_error: 7.8361
# Epoch 77/1000
# 251/251 [==============================] - 0s 172us/sample - loss: 6.4670 - mean_absolute_error: 1.7660 - mean_squared_error: 6.4670 - val_loss: 7.8657 - val_mean_absolute_error: 2.1569 - val_mean_squared_error: 7.8657
# Epoch 78/1000
# 251/251 [==============================] - 0s 150us/sample - loss: 6.5502 - mean_absolute_error: 1.8098 - mean_squared_error: 6.5502 - val_loss: 7.8582 - val_mean_absolute_error: 2.1506 - val_mean_squared_error: 7.8582
# Epoch 79/1000
# 251/251 [==============================] - 0s 165us/sample - loss: 6.4992 - mean_absolute_error: 1.7974 - mean_squared_error: 6.4992 - val_loss: 8.2628 - val_mean_absolute_error: 2.0909 - val_mean_squared_error: 8.2628
# Epoch 80/1000
# 251/251 [==============================] - 0s 161us/sample - loss: 6.6942 - mean_absolute_error: 1.8327 - mean_squared_error: 6.6942 - val_loss: 7.9202 - val_mean_absolute_error: 2.1251 - val_mean_squared_error: 7.9202
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_14372/4212951909.py in <module>
#     157
#     158 # Export model and save to GCS
# --> 159 model.save(BUCKET + '/mpg/model')
#     160
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures)
#    1169     """
#    1170     saving.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 1171                       signatures)
#    1172
#    1173   def save_weights(self, filepath, overwrite=True, save_format=None):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures)
#     107           'or using `save_weights`.')
#     108     hdf5_format.save_model_to_hdf5(
# --> 109         model, filepath, overwrite, include_optimizer)
#     110   else:
#     111     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      84         return
#      85
# ---> 86     f = h5py.File(filepath, mode='w')
#      87     opened_new_file = True
#      88   else:
#
# /opt/conda/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /opt/conda/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     177         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     178     elif mode == 'w':
# --> 179         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     180     elif mode == 'a':
#     181         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'gs://your-gcs-bucket/mpg/model', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)
